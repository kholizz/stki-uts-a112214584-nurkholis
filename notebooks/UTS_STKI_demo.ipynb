# %% [markdown]
# # UTS STKI Demo Notebook
# Isi dengan:
# - Preprocessing before/after (2 dokumen)
# - Boolean queries (≥3) + precision/recall
# - VSM top-k + P@k, MAP@k/nDCG@k
# - Perbandingan TF-IDF vs sublinear TF

# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # biar folder src bisa dikenali

from src.preprocess import preprocess_folder

report = preprocess_folder('../data/raw','../data/processed')
report[:2]
# Out:
# [('doc1.txt',
#   14,
#   [('sistem', 1),
#    ('informasi', 1),
#    ('akademik', 1),
#    ('guna', 1),
#    ('kelola', 1),
#    ('data', 1),
#    ('mahasiswa', 1),
#    ('jadwal', 1),
#    ('kuliah', 1),
#    ('nilai', 1)]),
#  ('doc2.txt',
#   15,
#   [('jaring', 1),
#    ('komputer', 1),
#    ('mungkin', 1),
#    ('komunikasi', 1),
#    ('data', 1),
#    ('antara', 1),
#    ('perangkat', 1),
#    ('lalu', 1),
#    ('media', 1),
#    ('transmisi', 1)])]
